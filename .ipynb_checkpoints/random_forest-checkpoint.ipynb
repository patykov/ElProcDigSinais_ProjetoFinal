# %%
import os
import time
import collections
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import normalize
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import average_precision_score, precision_recall_curve, precision_recall_fscore_support

# %%
### READING DATASET ###

# Paths
dataset_path = 'Dataset'
games_dir = next(os.walk(dataset_path))[1]

tag_to_skip = ['highlights', 'highlights2', '.DS_Store', '.git']
dt = np.dtype([('a', float), ('b', float), ('name', np.unicode_, 16)])

# Iterating through games
games_data = []
games_path = [os.path.join(dataset_path, g) for g in games_dir]
for path in games_path:
    game_name = os.path.basename(path)
    if game_name != 'ned_svk':
        game_info = os.listdir(path)
        data = collections.OrderedDict()
        for info in game_info:
            tag_name = os.path.splitext(info)[0]
            if tag_name not in tag_to_skip:
                csv_file = os.path.join(path, info)
                if tag_name == 'highlights_boundaries':
                    data_value = np.genfromtxt(csv_file, delimiter=',', dtype=None)
                else:
                    data_value = np.fromfile(csv_file, dtype=np.float64)
                data[tag_name] = data_value
            data['name'] = game_name
        games_data.append(data)

games_backup = games_data[:]

# %%
### REMOVENDO VALORES CORRELACIONADOS ###

to_remove = ['em_mcs_energy', 'em_mcs_energy_diff', 'em_mcs_energy_diff_ascending']
for game in games_data:
    for tag in to_remove:
        del game[tag]

# %%
### CRIANDO VETOR DE GT ###

normal_cases = ['Normal', 'Inicio', 'Fim']
to_skip = ['name', 'highlights_boundaries']

for game in games_data:
    h = game['highlights_boundaries']
    end = h[-1][0]
    gt = np.zeros(end)
    slices = []
    for line in h:
        tag = line[2].decode('UTF-8').split(' ')
        name = [t for t in tag if t != ''][0]
        if name not in normal_cases:
            gt[line[0]-1:line[1]] = 1
        else:
            slices.append([line[0], line[1], name])

    slices = slices[::-1]
    ## Removing data not to be considered ###
    for k, values in game.items():
        if k not in to_skip:
            for sl in slices:
                if 'Fim' in sl[2]:
                    values = np.delete(values, range(sl[0], len(values)))
                if 'Normal' in sl[2]:
                    values = np.delete(values, range(sl[0], sl[1]))
                if 'Inicio' in sl[2]:
                    values = np.delete(values, range(0, sl[0]))
        game[k] = values
                    
            
    game['gt'] = gt
    del game['highlights_boundaries']
# Out:
# /Users/admin/py3env/lib/python3.5/site-packages/ipykernel/__main__.py:27: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.

# %%
for game in games_data:
    print(game['name'])
    for k, v in game.items():
        print('\t{} - {}'.format(k, len(v)))
# Out:
# amg_vas
# 	dc_hue_mean - 72098
# 	name - 7
# 	dc_percent - 72098
# 	em_cs_energy - 72098
# 	em_cs_energy_diff - 72098
# 	em_cs_energy_diff_ascending - 72098
# 	em_st_energy - 72098
# 	em_st_energy_diff - 72098
# 	em_st_energy_diff_ascending - 72098
# 	pc_delta - 72098
# 	pc_rho - 72098
# 	pc_theta - 72098
# 	pc_var_delta - 72098
# 	pc_var_theta - 72098
# 	pm_pitch - 72098
# 	pm_pitch_diff - 72098
# 	pm_pitch_diff_ascending - 72098
# 	gt - 209234
# arg_ger
# 	dc_hue_mean - 52742
# 	name - 7
# 	dc_percent - 52742
# 	em_cs_energy - 52742
# 	em_cs_energy_diff - 52742
# 	em_cs_energy_diff_ascending - 52742
# 	em_st_energy - 52742
# 	em_st_energy_diff - 52742
# 	em_st_energy_diff_ascending - 52742
# 	pc_delta - 52742
# 	pc_rho - 52740
# 	pc_theta - 52742
# 	pc_var_delta - 52742
# 	pc_var_theta - 52742
# 	pm_pitch - 52742
# 	pm_pitch_diff - 52742
# 	pm_pitch_diff_ascending - 52742
# 	gt - 171536
# arg_mex
# 	dc_hue_mean - 81362
# 	name - 7
# 	dc_percent - 81362
# 	em_cs_energy - 81362
# 	em_cs_energy_diff - 81362
# 	em_cs_energy_diff_ascending - 81362
# 	em_st_energy - 81362
# 	em_st_energy_diff - 81362
# 	em_st_energy_diff_ascending - 81362
# 	pc_delta - 81362
# 	pc_rho - 81362
# 	pc_theta - 81362
# 	pc_var_delta - 81362
# 	pc_var_theta - 81362
# 	pm_pitch - 81362
# 	pm_pitch_diff - 81362
# 	pm_pitch_diff_ascending - 81362
# 	gt - 202368
# arg_nig
# 	dc_hue_mean - 80880
# 	name - 7
# 	dc_percent - 80880
# 	em_cs_energy - 80880
# 	em_cs_energy_diff - 80880
# 	em_cs_energy_diff_ascending - 80880
# 	em_st_energy - 80880
# 	em_st_energy_diff - 80880
# 	em_st_energy_diff_ascending - 80880
# 	pc_delta - 80880
# 	pc_rho - 80880
# 	pc_theta - 80880
# 	pc_var_delta - 80880
# 	pc_var_theta - 80880
# 	pm_pitch - 80880
# 	pm_pitch_diff - 80880
# 	pm_pitch_diff_ascending - 80880
# 	gt - 205865
# arg_sko
# 	dc_hue_mean - 77995
# 	name - 7
# 	dc_percent - 77995
# 	em_cs_energy - 77995
# 	em_cs_energy_diff - 77995
# 	em_cs_energy_diff_ascending - 77995
# 	em_st_energy - 77995
# 	em_st_energy_diff - 77995
# 	em_st_energy_diff_ascending - 77995
# 	pc_delta - 77995
# 	pc_rho - 77995
# 	pc_theta - 77995
# 	pc_var_delta - 77995
# 	pc_var_theta - 77995
# 	pm_pitch - 77995
# 	pm_pitch_diff - 77995
# 	pm_pitch_diff_ascending - 77995
# 	gt - 200918
# bar_int
# 	dc_hue_mean - 61005
# 	name - 7
# 	dc_percent - 61005
# 	em_cs_energy - 61005
# 	em_cs_energy_diff - 61005
# 	em_cs_energy_diff_ascending - 61005
# 	em_st_energy - 61005
# 	em_st_energy_diff - 61005
# 	em_st_energy_diff_ascending - 61005
# 	pc_delta - 61005
# 	pc_rho - 61005
# 	pc_theta - 61005
# 	pc_var_delta - 61005
# 	pc_var_theta - 61005
# 	pm_pitch - 61005
# 	pm_pitch_diff - 61005
# 	pm_pitch_diff_ascending - 61005
# 	gt - 164261
# bay_int
# 	dc_hue_mean - 73469
# 	name - 7
# 	dc_percent - 73469
# 	em_cs_energy - 73469
# 	em_cs_energy_diff - 73469
# 	em_cs_energy_diff_ascending - 73469
# 	em_st_energy - 73469
# 	em_st_energy_diff - 73469
# 	em_st_energy_diff_ascending - 73469
# 	pc_delta - 73469
# 	pc_rho - 73469
# 	pc_theta - 73469
# 	pc_var_delta - 73469
# 	pc_var_theta - 73469
# 	pm_pitch - 73469
# 	pm_pitch_diff - 73469
# 	pm_pitch_diff_ascending - 73469
# 	gt - 210620
# bra_chi
# 	dc_hue_mean - 79577
# 	name - 7
# 	dc_percent - 79577
# 	em_cs_energy - 79577
# 	em_cs_energy_diff - 79577
# 	em_cs_energy_diff_ascending - 79577
# 	em_st_energy - 79577
# 	em_st_energy_diff - 79577
# 	em_st_energy_diff_ascending - 79577
# 	pc_delta - 79577
# 	pc_rho - 79577
# 	pc_theta - 79577
# 	pc_var_delta - 79577
# 	pc_var_theta - 79577
# 	pm_pitch - 79577
# 	pm_pitch_diff - 79577
# 	pm_pitch_diff_ascending - 79577
# 	gt - 197484
# bra_ita
# 	dc_hue_mean - 65303
# 	name - 7
# 	dc_percent - 65303
# 	em_cs_energy - 65303
# 	em_cs_energy_diff - 65303
# 	em_cs_energy_diff_ascending - 65303
# 	em_st_energy - 65303
# 	em_st_energy_diff - 65303
# 	em_st_energy_diff_ascending - 65303
# 	pc_delta - 65303
# 	pc_rho - 65303
# 	pc_theta - 65303
# 	pc_var_delta - 65303
# 	pc_var_theta - 65303
# 	pm_pitch - 65303
# 	pm_pitch_diff - 65303
# 	pm_pitch_diff_ascending - 65303
# 	gt - 214644
# bra_ned
# 	dc_hue_mean - 80361
# 	name - 7
# 	dc_percent - 80361
# 	em_cs_energy - 80361
# 	em_cs_energy_diff - 80361
# 	em_cs_energy_diff_ascending - 80361
# 	em_st_energy - 80361
# 	em_st_energy_diff - 80361
# 	em_st_energy_diff_ascending - 80361
# 	pc_delta - 80361
# 	pc_rho - 80361
# 	pc_theta - 80361
# 	pc_var_delta - 80361
# 	pc_var_theta - 80361
# 	pm_pitch - 80361
# 	pm_pitch_diff - 80361
# 	pm_pitch_diff_ascending - 80361
# 	gt - 199709
# chi_swi
# 	dc_hue_mean - 80129
# 	name - 7
# 	dc_percent - 80129
# 	em_cs_energy - 80129
# 	em_cs_energy_diff - 80129
# 	em_cs_energy_diff_ascending - 80129
# 	em_st_energy - 80129
# 	em_st_energy_diff - 80129
# 	em_st_energy_diff_ascending - 80129
# 	pc_delta - 80129
# 	pc_rho - 80129
# 	pc_theta - 80129
# 	pc_var_delta - 80129
# 	pc_var_theta - 80129
# 	pm_pitch - 80129
# 	pm_pitch_diff - 80129
# 	pm_pitch_diff_ascending - 80129
# 	gt - 204272
# cor_flu
# 	dc_hue_mean - 65794
# 	name - 7
# 	dc_percent - 65794
# 	em_cs_energy - 65794
# 	em_cs_energy_diff - 65794
# 	em_cs_energy_diff_ascending - 65794
# 	em_st_energy - 65794
# 	em_st_energy_diff - 65794
# 	em_st_energy_diff_ascending - 65794
# 	pc_delta - 65794
# 	pc_rho - 65794
# 	pc_theta - 65794
# 	pc_var_delta - 65794
# 	pc_var_theta - 65794
# 	pm_pitch - 65794
# 	pm_pitch_diff - 65794
# 	pm_pitch_diff_ascending - 65794
# 	gt - 219759
# cru_spo
# 	dc_hue_mean - 66140
# 	name - 7
# 	dc_percent - 66140
# 	em_cs_energy - 66140
# 	em_cs_energy_diff - 66140
# 	em_cs_energy_diff_ascending - 66140
# 	em_st_energy - 66140
# 	em_st_energy_diff - 66140
# 	em_st_energy_diff_ascending - 66140
# 	pc_delta - 66140
# 	pc_rho - 66140
# 	pc_theta - 66140
# 	pc_var_delta - 66140
# 	pc_var_theta - 66140
# 	pm_pitch - 66140
# 	pm_pitch_diff - 66140
# 	pm_pitch_diff_ascending - 66140
# 	gt - 219949
# den_jap
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 200063
# fra_mex
# 	dc_hue_mean - 80147
# 	name - 7
# 	dc_percent - 80147
# 	em_cs_energy - 80147
# 	em_cs_energy_diff - 80147
# 	em_cs_energy_diff_ascending - 80147
# 	em_st_energy - 80147
# 	em_st_energy_diff - 80147
# 	em_st_energy_diff_ascending - 80147
# 	pc_delta - 80147
# 	pc_rho - 80147
# 	pc_theta - 80147
# 	pc_var_delta - 80147
# 	pc_var_theta - 80147
# 	pm_pitch - 80147
# 	pm_pitch_diff - 80147
# 	pm_pitch_diff_ascending - 80147
# 	gt - 201324
# ger_eng
# 	dc_hue_mean - 78293
# 	name - 7
# 	dc_percent - 78293
# 	em_cs_energy - 78293
# 	em_cs_energy_diff - 78293
# 	em_cs_energy_diff_ascending - 78293
# 	em_st_energy - 78293
# 	em_st_energy_diff - 78293
# 	em_st_energy_diff_ascending - 78293
# 	pc_delta - 78293
# 	pc_rho - 78293
# 	pc_theta - 78293
# 	pc_var_delta - 78293
# 	pc_var_theta - 78293
# 	pm_pitch - 78293
# 	pm_pitch_diff - 78293
# 	pm_pitch_diff_ascending - 78293
# 	gt - 196687
# ger_spa
# 	dc_hue_mean - 82698
# 	name - 7
# 	dc_percent - 82698
# 	em_cs_energy - 82698
# 	em_cs_energy_diff - 82698
# 	em_cs_energy_diff_ascending - 82698
# 	em_st_energy - 82698
# 	em_st_energy_diff - 82698
# 	em_st_energy_diff_ascending - 82698
# 	pc_delta - 82698
# 	pc_rho - 82698
# 	pc_theta - 82698
# 	pc_var_delta - 82698
# 	pc_var_theta - 82698
# 	pm_pitch - 82698
# 	pm_pitch_diff - 82698
# 	pm_pitch_diff_ascending - 82698
# 	gt - 198728
# ger_uru
# 	dc_hue_mean - 81046
# 	name - 7
# 	dc_percent - 81046
# 	em_cs_energy - 81046
# 	em_cs_energy_diff - 81046
# 	em_cs_energy_diff_ascending - 81046
# 	em_st_energy - 81046
# 	em_st_energy_diff - 81046
# 	em_st_energy_diff_ascending - 81046
# 	pc_delta - 81046
# 	pc_rho - 81046
# 	pc_theta - 81046
# 	pc_var_delta - 81046
# 	pc_var_theta - 81046
# 	pm_pitch - 81046
# 	pm_pitch_diff - 81046
# 	pm_pitch_diff_ascending - 81046
# 	gt - 199785
# ita_svk
# 	dc_hue_mean - 81579
# 	name - 7
# 	dc_percent - 81579
# 	em_cs_energy - 81579
# 	em_cs_energy_diff - 81579
# 	em_cs_energy_diff_ascending - 81579
# 	em_st_energy - 81579
# 	em_st_energy_diff - 81579
# 	em_st_energy_diff_ascending - 81579
# 	pc_delta - 81579
# 	pc_rho - 81579
# 	pc_theta - 81579
# 	pc_var_delta - 81579
# 	pc_var_theta - 81579
# 	pm_pitch - 81579
# 	pm_pitch_diff - 81579
# 	pm_pitch_diff_ascending - 81579
# 	gt - 206667
# ned_jap
# 	dc_hue_mean - 81342
# 	name - 7
# 	dc_percent - 81342
# 	em_cs_energy - 81342
# 	em_cs_energy_diff - 81342
# 	em_cs_energy_diff_ascending - 81342
# 	em_st_energy - 81342
# 	em_st_energy_diff - 81342
# 	em_st_energy_diff_ascending - 81342
# 	pc_delta - 81342
# 	pc_rho - 81342
# 	pc_theta - 81342
# 	pc_var_delta - 81342
# 	pc_var_theta - 81342
# 	pm_pitch - 81342
# 	pm_pitch_diff - 81342
# 	pm_pitch_diff_ascending - 81342
# 	gt - 200203
# por_nko
# 	dc_hue_mean - 77183
# 	name - 7
# 	dc_percent - 77183
# 	em_cs_energy - 77183
# 	em_cs_energy_diff - 77183
# 	em_cs_energy_diff_ascending - 77183
# 	em_st_energy - 77183
# 	em_st_energy_diff - 77183
# 	em_st_energy_diff_ascending - 77183
# 	pc_delta - 77183
# 	pc_rho - 77183
# 	pc_theta - 77183
# 	pc_var_delta - 77183
# 	pc_var_theta - 77183
# 	pm_pitch - 77183
# 	pm_pitch_diff - 77183
# 	pm_pitch_diff_ascending - 77183
# 	gt - 204334
# san_vas
# 	dc_hue_mean - 70592
# 	name - 7
# 	dc_percent - 70592
# 	em_cs_energy - 70592
# 	em_cs_energy_diff - 70592
# 	em_cs_energy_diff_ascending - 70592
# 	em_st_energy - 70592
# 	em_st_energy_diff - 70592
# 	em_st_energy_diff_ascending - 70592
# 	pc_delta - 70592
# 	pc_rho - 70592
# 	pc_theta - 70592
# 	pc_var_delta - 70592
# 	pc_var_theta - 70592
# 	pm_pitch - 70592
# 	pm_pitch_diff - 70592
# 	pm_pitch_diff_ascending - 70592
# 	gt - 212140
# spa_ned
# 	dc_hue_mean - 82756
# 	name - 7
# 	dc_percent - 82756
# 	em_cs_energy - 82756
# 	em_cs_energy_diff - 82756
# 	em_cs_energy_diff_ascending - 82756
# 	em_st_energy - 82756
# 	em_st_energy_diff - 82756
# 	em_st_energy_diff_ascending - 82756
# 	pc_delta - 82756
# 	pc_rho - 82756
# 	pc_theta - 82756
# 	pc_var_delta - 82756
# 	pc_var_theta - 82756
# 	pm_pitch - 82756
# 	pm_pitch_diff - 82756
# 	pm_pitch_diff_ascending - 82756
# 	gt - 200150
# spa_por
# 	dc_hue_mean - 82002
# 	name - 7
# 	dc_percent - 82002
# 	em_cs_energy - 82002
# 	em_cs_energy_diff - 82002
# 	em_cs_energy_diff_ascending - 82002
# 	em_st_energy - 82002
# 	em_st_energy_diff - 82002
# 	em_st_energy_diff_ascending - 82002
# 	pc_delta - 82002
# 	pc_rho - 82002
# 	pc_theta - 82002
# 	pc_var_delta - 82002
# 	pc_var_theta - 82002
# 	pm_pitch - 82002
# 	pm_pitch_diff - 82002
# 	pm_pitch_diff_ascending - 82002
# 	gt - 204167
# spa_swi
# 	dc_hue_mean - 81509
# 	name - 7
# 	dc_percent - 81509
# 	em_cs_energy - 81509
# 	em_cs_energy_diff - 81509
# 	em_cs_energy_diff_ascending - 81509
# 	em_st_energy - 81509
# 	em_st_energy_diff - 81509
# 	em_st_energy_diff_ascending - 81509
# 	pc_delta - 81509
# 	pc_rho - 81509
# 	pc_theta - 81509
# 	pc_var_delta - 81509
# 	pc_var_theta - 81509
# 	pm_pitch - 81509
# 	pm_pitch_diff - 81509
# 	pm_pitch_diff_ascending - 81509
# 	gt - 197798
# spa_usa
# 	dc_hue_mean - 55472
# 	name - 7
# 	dc_percent - 55472
# 	em_cs_energy - 55472
# 	em_cs_energy_diff - 55472
# 	em_cs_energy_diff_ascending - 55472
# 	em_st_energy - 55472
# 	em_st_energy_diff - 55472
# 	em_st_energy_diff_ascending - 55472
# 	pc_delta - 55472
# 	pc_rho - 55472
# 	pc_theta - 55472
# 	pc_var_delta - 55472
# 	pc_var_theta - 55472
# 	pm_pitch - 55472
# 	pm_pitch_diff - 55472
# 	pm_pitch_diff_ascending - 55472
# 	gt - 215780
# spo_cru
# 	dc_hue_mean - 59414
# 	name - 7
# 	dc_percent - 59414
# 	em_cs_energy - 59414
# 	em_cs_energy_diff - 59414
# 	em_cs_energy_diff_ascending - 59414
# 	em_st_energy - 59414
# 	em_st_energy_diff - 59414
# 	em_st_energy_diff_ascending - 59414
# 	pc_delta - 59414
# 	pc_rho - 59414
# 	pc_theta - 59414
# 	pc_var_delta - 59414
# 	pc_var_theta - 59414
# 	pm_pitch - 59414
# 	pm_pitch_diff - 59414
# 	pm_pitch_diff_ascending - 59414
# 	gt - 218146
# uru_ned
# 	dc_hue_mean - 83336
# 	name - 7
# 	dc_percent - 83336
# 	em_cs_energy - 83336
# 	em_cs_energy_diff - 83336
# 	em_cs_energy_diff_ascending - 83336
# 	em_st_energy - 83336
# 	em_st_energy_diff - 83336
# 	em_st_energy_diff_ascending - 83336
# 	pc_delta - 83336
# 	pc_rho - 83336
# 	pc_theta - 83336
# 	pc_var_delta - 83336
# 	pc_var_theta - 83336
# 	pm_pitch - 83336
# 	pm_pitch_diff - 83336
# 	pm_pitch_diff_ascending - 83336
# 	gt - 203934
# uru_sko
# 	dc_hue_mean - 79424
# 	name - 7
# 	dc_percent - 79424
# 	em_cs_energy - 79424
# 	em_cs_energy_diff - 79424
# 	em_cs_energy_diff_ascending - 79424
# 	em_st_energy - 79424
# 	em_st_energy_diff - 79424
# 	em_st_energy_diff_ascending - 79424
# 	pc_delta - 79424
# 	pc_rho - 79424
# 	pc_theta - 79424
# 	pc_var_delta - 79424
# 	pc_var_theta - 79424
# 	pm_pitch - 79424
# 	pm_pitch_diff - 79424
# 	pm_pitch_diff_ascending - 79424
# 	gt - 200568

# %%
### CORTANDO VALORES EXCEDENTES PARA QUE TODOS OS DADOS TENHAM O MESMO TAMANHO ###

for game in games_data:
    values = [len(v) for k, v in game.items() if k not in ['name']]
    min_l = min(values)
    for k, v in game.items():
        if len(v) > min_l:
            game[k] = v[:min_l]
            

### ZERO PADDING ###
max_length = 0
for game in games_data:
    values = [len(v) for k, v in game.items() if k not in ['name']]
    max_length = max(values) if max(values)>max_length else max_length

for game in games_data:
    for k, v in game.items():
        if k not in ['name']:
            zero_v = np.zeros(max_length)
            if len(v) < max_length:
                zero_v[:len(v)] = v
                game[k] = zero_v

# %%
for game in games_data:
    print(game['name'])
    for k, v in game.items():
        print('\t{} - {}'.format(k, len(v)))
# Out:
# amg_vas
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# arg_ger
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# arg_mex
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# arg_nig
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# arg_sko
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# bar_int
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# bay_int
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# bra_chi
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# bra_ita
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# bra_ned
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# chi_swi
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# cor_flu
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# cru_spo
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# den_jap
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# fra_mex
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# ger_eng
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# ger_spa
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# ger_uru
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# ita_svk
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# ned_jap
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# por_nko
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# san_vas
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# spa_ned
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# spa_por
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# spa_swi
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# spa_usa
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# spo_cru
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# uru_ned
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370
# uru_sko
# 	dc_hue_mean - 83370
# 	name - 7
# 	dc_percent - 83370
# 	em_cs_energy - 83370
# 	em_cs_energy_diff - 83370
# 	em_cs_energy_diff_ascending - 83370
# 	em_st_energy - 83370
# 	em_st_energy_diff - 83370
# 	em_st_energy_diff_ascending - 83370
# 	pc_delta - 83370
# 	pc_rho - 83370
# 	pc_theta - 83370
# 	pc_var_delta - 83370
# 	pc_var_theta - 83370
# 	pm_pitch - 83370
# 	pm_pitch_diff - 83370
# 	pm_pitch_diff_ascending - 83370
# 	gt - 83370

# %%
### DIVIDING SPLITS FROM TRAIN, EVAL, TEST ###

from sklearn.model_selection import train_test_split

games_name = [g['name'] for g in games_data]
games_train1, games_test = train_test_split(games_name, test_size=0.15)
games_train2, games_val = train_test_split(games_train1, test_size=0.05)

print('Total train: {}'.format(len(games_train2)))
print('Total test: {}'.format(len(games_test)))
print('Total val: {}'.format(len(games_val)))
# Out:
# Total train: 22
# Total test: 5
# Total val: 2

# %%
for i, tag_name in enumerate(games_data[10].keys()):
    print('{} - {}'.format(i, tag_name))
    if tag_name == 'name':
        name_id = i
    if tag_name == 'gt':
        gt_id = i
        
print('\nnome_id: {}, gt_id: {}'.format(name_id, gt_id))
# Out:
# 0 - dc_hue_mean
# 1 - name
# 2 - dc_percent
# 3 - em_cs_energy
# 4 - em_cs_energy_diff
# 5 - em_cs_energy_diff_ascending
# 6 - em_st_energy
# 7 - em_st_energy_diff
# 8 - em_st_energy_diff_ascending
# 9 - pc_delta
# 10 - pc_rho
# 11 - pc_theta
# 12 - pc_var_delta
# 13 - pc_var_theta
# 14 - pm_pitch
# 15 - pm_pitch_diff
# 16 - pm_pitch_diff_ascending
# 17 - gt
#
# nome_id: 1, gt_id: 17

# %%
X_train = []
y_train = []

for game in games_data:
    if game['name'] in games_train1:
        values_array = np.array(list(game.values()))
        # Getting GT
        y_train += list(values_array[gt_id])
        
        # Removing name and GT to train
        values_array = np.delete(values_array, (max(name_id, gt_id)), axis=0)
        values_array = np.delete(values_array, (min(name_id, gt_id)), axis=0)
        
        values_array = np.array(values_array[:].tolist())
        if len(X_train) == 0:
            X_train = np.transpose(values_array)
        else:
            X_train = np.concatenate((X_train, np.transpose(values_array)))
y_train = np.array(y_train)    


X_test = []
y_test = []

for game in games_data:
    if game['name'] in games_test:
        values_array = np.array(list(game.values()))
        # Getting GT
        y_test += list(values_array[gt_id])
        
        # Removing name and GT to train
        values_array = np.delete(values_array, (max(name_id, gt_id)), axis=0)
        values_array = np.delete(values_array, (min(name_id, gt_id)), axis=0)
        
        values_array = np.array(values_array[:].tolist())
        if len(X_test) == 0:
            X_test = np.transpose(values_array)
        else:
            X_test = np.concatenate((X_test, np.transpose(values_array)))
y_test = np.array(y_test)
            

print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (2000880, 16) (2000880,)
# Test (416850, 16) (416850,)

# %%
print('Train')
print(np.mean(X_train, axis=0))
print(np.std(X_train, axis=0))
print('\nTest')
print(np.mean(X_test, axis=0))
print(np.std(X_test, axis=0))

normalize(X_train, axis=1, copy=False)
normalize(X_test, axis=1, copy=False)

print('\nTrain normalized')
print(np.mean(X_train, axis=0))
print(np.std(X_train, axis=0))
print('\nTest normalized')
print(np.mean(X_test, axis=0))
print(np.std(X_test, axis=0))
# Out:
# Train
# [  2.02406063e-034   1.96722213e-034   2.16851697e-034   2.27555553e-034
#    2.69001240e-260   2.22923596e-034   2.14630690e-034   2.69001240e-260
#    9.77682352e-036   2.69163096e-260   4.50524854e-035   7.58557143e-035
#    1.07951913e-034   1.65337640e-034   1.78172418e-034   2.69001240e-260]
# [  8.48554817e-34   8.40836038e-34   8.92947848e-34   9.12771418e-34
#    0.00000000e+00   9.02579248e-34   8.84164191e-34   0.00000000e+00
#    1.99888685e-34   0.00000000e+00   3.66969212e-34   5.45442384e-34
#    6.31554818e-34   7.72499208e-34   7.99823813e-34   0.00000000e+00]
#
# Test
# [  1.90685893e-034   1.87860571e-034   2.01742496e-034   2.16828825e-034
#    2.57908172e-260   2.14573623e-034   2.07565603e-034   2.57908172e-260
#    8.41576601e-036   2.58063969e-260   4.00416774e-035   6.58340517e-035
#    1.00215908e-034   1.56112880e-034   1.73041698e-034   2.57908172e-260]
# [  8.33210746e-34   8.24958253e-34   8.63269173e-34   8.92373756e-34
#    0.00000000e+00   8.87670032e-34   8.70405979e-34   0.00000000e+00
#    1.89187592e-34   0.00000000e+00   3.46077746e-34   5.07936675e-34
#    6.07528047e-34   7.52773589e-34   7.89160145e-34   0.00000000e+00]
#
# Train normalized
# [  1.27712326e-001   1.16598545e-001   1.11871723e-001   1.19100758e-001
#    1.42467158e-188   1.16342801e-001   1.12479982e-001   1.42467158e-188
#    7.08185371e-003   1.42560060e-188   2.73222578e-002   3.44344153e-002
#    5.39237028e-002   8.80615624e-002   9.44872600e-002   1.42467158e-188]
# [ 0.31434265  0.30215059  0.29701333  0.30512559  0.          0.30200478
#   0.29752435  0.          0.07843727  0.          0.15390113  0.17180191
#   0.21282581  0.26650992  0.27512022  0.        ]
#
# Test normalized
# [  1.13447088e-001   1.13747819e-001   1.07113817e-001   1.16848355e-001
#    1.03632187e-188   1.14019084e-001   1.11109950e-001   1.03632187e-188
#    5.34487817e-003   1.03684528e-188   2.29418978e-002   3.23278554e-002
#    5.04689657e-002   8.47381093e-002   9.41252552e-002   1.03632187e-188]
# [ 0.29903117  0.29944678  0.29178387  0.3028918   0.          0.29938257
#   0.2963495   0.          0.06832393  0.          0.14166973  0.16677771
#   0.20649874  0.26230346  0.27495229  0.        ]

# %%
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (2000880, 16) (2000880,)
# Test (416850, 16) (416850,)

# %%
estimators = [10, 50, 100, 120, 150]
models = []
for n_est in estimators:
    clf = RandomForestClassifier(class_weight='balanced', n_estimators=n_est, verbose=1, n_jobs=-1)
    clf.fit(X_train, y_train)
    models.append(clf)
    print(clf)

    # Getting predictions
    y_predictions = clf.predict_proba(X_test)
    y_score = clf.predict(X_test)

    # Calculating average precision
    average_precision = average_precision_score(y_test, y_score)
    print('Average precision-recall score: {0:0.2f}'.format(average_precision))

    # Getting precision and recall
    p_r_fs = precision_recall_fscore_support(y_test, y_score)
    print('Precision: {}'.format(p_r_fs[0]))
    print('Recall: {}'.format(p_r_fs[1]))

    print(confusion_matrix(y_test,y_score))

    # Plotting PR curve
    precision, recall, _ = precision_recall_curve(y_test, y_predictions[:, 1])

    plt.step(recall, precision, color='b', alpha=0.2, where='post')
    plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))
    plt.show()
    print('\n--------------------------------------------------------------')
# Out:
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.5min finished
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=1, warm_start=False)
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:    1.2s finished
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:    1.1s finished
# Average precision-recall score: 0.01
# Precision: [ 0.9897285   0.01312361]
# Recall: [ 0.56894347  0.49259645]
# [[234436 177619]
#  [  2433   2362]]
# --------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  7.7min finished
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=1, warm_start=False)
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    6.2s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    5.6s finished
# Average precision-recall score: 0.01
# Precision: [ 0.98967871  0.01307171]
# Recall: [ 0.57105726  0.48821689]
# [[235307 176748]
#  [  2454   2341]]
# --------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 13.5min finished
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-1, oob_score=False,
#             random_state=None, verbose=1, warm_start=False)
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:   10.4s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    9.9s finished
# Average precision-recall score: 0.01
# Precision: [ 0.9897376   0.01313894]
# Recall: [ 0.56945311  0.49259645]
# [[234646 177409]
#  [  2433   2362]]
# --------------------------------------------------------------

# %%
new_keys = list(games_data[0].keys())
new_keys.remove('gt')
new_keys.remove('name')

for feature in range(X_train.shape[1]):
    new_X_train = X_train[:, feature]
    new_X_test = X_test[:, feature]
    
#     start_time = time.clock()
    new_clf = RandomForestClassifier(class_weight='balanced')
    new_clf.fit(new_X_train[:, None], y_train)
    
    new_y_score = new_clf.predict(new_X_test[:, None])
    new_average_precision = average_precision_score(y_test, new_y_score)
    new_p_r_fs = precision_recall_fscore_support(y_test, new_y_score)
    
    tp = [0, 0]
    fp = [0, 0]

    for i, label in enumerate(y_test):
        label = int(label)
        if int(new_y_score[i]) == label:
            tp[label] += 1
        if int(new_y_score[i]) != label:
            fp[label] += 1

    print('{} - {}'.format(feature, new_keys[feature]))
    print('\tAverage precision-recall score: {0:0.2f}'.format(new_average_precision))
    print('\tPrecision: {}'.format(new_p_r_fs[0]))
    print('\tRecall: {}'.format(new_p_r_fs[1]))
    print(tp)
    print(fp)
#     print('\tTime: {:.5f} seconds'.format(time.clock() - start_time))
# Out:
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0 - pc_var_delta
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 1 - pc_var_theta
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2 - em_cs_energy_diff
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.          0.01079045]
# 	Recall: [ 0.  1.]
# [0, 4498]
# [412352, 0]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 3 - dc_percent
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 4 - pc_theta
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 5 - pm_pitch_diff_ascending
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 6 - pm_pitch
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 7 - pm_pitch_diff
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.          0.01079045]
# 	Recall: [ 0.  1.]
# [0, 4498]
# [412352, 0]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 8 - dc_hue_mean
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.          0.01079045]
# 	Recall: [ 0.  1.]
# [0, 4498]
# [412352, 0]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 9 - em_st_energy_diff
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 10 - em_st_energy_diff_ascending
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 11 - pc_delta
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.          0.01079045]
# 	Recall: [ 0.  1.]
# [0, 4498]
# [412352, 0]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 12 - pc_rho
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 13 - em_st_energy
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.98920955  0.        ]
# 	Recall: [ 1.  0.]
# [412352, 0]
# [0, 4498]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 14 - em_cs_energy_diff_ascending
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.          0.01079045]
# 	Recall: [ 0.  1.]
# [0, 4498]
# [412352, 0]
# /Users/admin/py3env/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 15 - em_cs_energy
# 	Average precision-recall score: 0.01
# 	Precision: [ 0.          0.01079045]
# 	Recall: [ 0.  1.]
# [0, 4498]
# [412352, 0]

# %%
new_keys = list(games_data[0].keys())
new_keys.remove('gt')
new_keys.remove('name')

for feature1 in range(X_train.shape[1]):
    new_X_train1 = X_train[:, feature1]
    new_X_test1 = X_test[:, feature1]
    for feature2 in range(feature1, X_train.shape[1]):
        new_X_train2 = X_train[:, feature2]
        new_X_test2 = X_test[:, feature2]
        
        new_X_train = np.concatenate((new_X_train1, new_X_train2), axis=0)
        
        print(new_X_train.shape)
        raise Exception

        start_time = time.clock()
        new_clf = RandomForestClassifier()
        new_clf.fit(new_X_train[:, None], y_train)

        new_y_score = new_clf.predict(new_X_test[:, None])
        new_average_precision = average_precision_score(y_test, new_y_score)
        new_p_r_fs = precision_recall_fscore_support(y_test, new_y_score)

        print(new_keys[feature])
        print('\tAverage precision-recall score: {0:0.2f}'.format(new_average_precision))
        print('\tPrecision: {}'.format(new_p_r_fs[0]))
        print('\tRecall: {}'.format(new_p_r_fs[1]))
        print('\tTime: {:.5f} seconds'.format(time.clock() - start_time))

# %%
new_keys
